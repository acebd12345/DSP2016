# %%
import numpy as np
import pylab as pl
import pandas as pd
import thinkplot as tp
import matplotlib.pyplot as plt
# %matplotlib inline
f=open('_taiwanStock.csv')
s=f.read()
sL=s.split('\n')
xL=[x.split(',')[-1] for x in sL]
yL=[float(x) for x in xL[1:-4]]
pData=np.array(yL)

# %%
len(pData)
# Out:
# 13508

# %%
print(pData[13495:13505])
# Out:
# [ 8490.25  8541.5   8562.59  8531.18  8652.08  8667.71  8700.39  8666.01
#   8633.72  8514.48]

# %%
import thinkdsp as td
def movingAverage(x, length):
    y= np.convolve(x, np.ones(length)/length)
    y= y[:len(x)]
    return y

ma100= movingAverage(pData, 100)
ma1000= movingAverage(pData, 1000)
ma10000= movingAverage(pData, 10000)
pl.plot(priceData)
pl.plot(ma100)
pl.plot(ma1000)
pl.plot(ma10000)

# %%
df = pd.read_csv('_taiwanStock.csv', nrows=13505, parse_dates=[0])
ys = df.Point.values
ts = np.arange(len(ys))

# %%
wave = td.Wave(ys, ts, framerate=1)
wave.plot()

# %%
spectrum = wave.make_spectrum()
priceSpec=spectrum

# %%
rNoise=td.BrownianNoise()
signal = td.BrownianNoise()
wave = signal.make_wave(duration=5, framerate=13505)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.plot()

# %%
signal = td.PinkNoise(beta=0)
PNoise=td.PinkNoise()
wave = signal.make_wave(duration=5, framerate=13505)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.plot()

# %%
signal = td.UncorrelatedUniformNoise()
WNoise=td.UncorrelatedUniformNoise()
wave = signal.make_wave(duration=5, framerate=13505)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.plot()
