# %%
from turtle import *
color('black', 'blue')
begin_fill()
lt(30)
circle(150,300)
end_fill()
color('black', 'white')
penup()
rt(-30)
fd(135)
lt(30)
begin_fill()
circle(120,300)
end_fill()
penup()
rt(-30)
fd(60)
lt(90)
fd(225)
color('black', 'white')
pendown()
begin_fill()
circle(25,360)
lt(180)
circle(25,360)
end_fill()
penup()
rt(90)
fd(12.5)
pendown()
pensize(5)
circle(2.5,360)
penup()
rt(180)
fd(25)
rt(90)
pendown()
circle(2.5,360)
rt(90)
penup()
fd(12.5)
lt(90)
fd(50)
pendown()
color('black', 'red')
begin_fill()
lt(90)
circle(15,360)
end_fill()
rt(90)
fd(80)
rt(90)
begin_fill()
circle(30,360)
end_fill()
penup()
fd(50)
pendown()
fd(80)
penup()
bk(180)
pendown()
bk(80)
penup()
fd(260)
rt(90)
fd(50)
pendown()
rt(110)
fd(80)
penup()
fd(120)
pendown()
fd(80)
lt(110)
penup()
fd(100)
pendown()
lt(115)
fd(80)
penup()
fd(120)
pendown()
fd(80)
lt(60)
penup()
fd(40)
lt(95)
pencolor("red")
pensize(30)
pendown()
fd(250)
penup()
bk(150)
rt(90)
pensize(5)
color('black', 'yellow')
begin_fill()
circle(30,360)
end_fill()
done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-1-bb2a451aa1dc> in <module>()
#      11 lt(30)
#      12 begin_fill()
# ---> 13 circle(120,300)
#      14 end_fill()
#      15 penup()
#
# C:\Users\阿凸\Anaconda3\lib\turtle.py in circle(radius, extent, steps)
#
# C:\Users\阿凸\Anaconda3\lib\turtle.py in circle(self, radius, extent, steps)
#    1989         for i in range(steps):
#    1990             self.speed(speed)
# -> 1991             self._go(l)
#    1992             self.speed(0)
#    1993             self._rotate(w)
#
# C:\Users\阿凸\Anaconda3\lib\turtle.py in _go(self, distance)
#    1603         """move turtle forward by specified distance"""
#    1604         ende = self._position + self._orient * distance
# -> 1605         self._goto(ende)
#    1606
#    1607     def _rotate(self, angle):
#
# C:\Users\阿凸\Anaconda3\lib\turtle.py in _goto(self, end)
# ...
